# %%
import sys
print(sys.executable)
# Out:
# C:\miniconda3\envs\deeplearning\python.exe

# %%
from huggingface_hub import HfApi
api = HfApi(token=os.environ.get('HUGGINGFACE_TOKEN'))
print(api.whoami()['name']) # confirms authentication
# Out:
# FonyuyGita

# %%
from datasets import load_dataset
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"
# ■■ LOAD A DATASET FROM THE HUB ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# The 'imdb' dataset — 50k movie reviews for sentiment analysis
ds = load_dataset('stanfordnlp/imdb')
# ds = load_dataset('imdb', trust_remote_code=True)
print(ds) # DatasetDict with 'train' and 'test' splits
# Access splits
train_ds = ds['train']
print(len(train_ds)) # 25000
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })
# 25000

# %%
# print the features
print(train_ds.features)
# Out:
# {'text': Value('string'), 'label': ClassLabel(names=['neg', 'pos'])}

# %%
print(train_ds[0])
# Out:
# {'text': 'I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far 
# ...

# %%
import pandas as pd
df=train_ds.to_pandas()
print(df.head())
# Out:
#                                                 text  label
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1  "I Am Curious: Yellow" is a risible and preten...      0
# 2  If only to avoid making this type of film in t...      0
# 3  This film was probably inspired by Godard's Ma...      0
# 4  Oh, brother...after hearing about this ridicul...      0

# %%
# STREAMING: FOR DATASETS TOO LARGE  TO FIT  IN RAM
# does not dwonload the entire datasets
import os
from datasets import load_dataset

os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# Added trust_remote_code=True
ds_stream = load_dataset(
    'wikimedia/wikipedia', 
     '20231101.simple', 
    split='train', 
    streaming=True, 

)

print("hello world")
for sample in ds_stream.take(3):
    print(sample['title'])
# Out:
# hello world
# '_ssl.c:1000: The handshake operation timed out' thrown while requesting GET https://huggingface.co/datasets/wikimedia/wikipedia/resolve/b04c8d1ceb2f5cd4588862100d08de323dccfbaa/20231101.simple/train-00000-of-00001.parquet
# Retrying in 1s [Retry 1/5].
# 'The read operation timed out' thrown while requesting GET https://huggingface.co/datasets/wikimedia/wikipedia/resolve/b04c8d1ceb2f5cd4588862100d08de323dccfbaa/20231101.simple/train-00000-of-00001.parquet
# Retrying in 1s [Retry 1/5].
# '_ssl.c:1000: The handshake operation timed out' thrown while requesting GET https://huggingface.co/datasets/wikimedia/wikipedia/resolve/b04c8d1ceb2f5cd4588862100d08de323dccfbaa/20231101.simple/train-00000-of-00001.parquet
# Retrying in 2s [Retry 2/5].
# 'The read operation timed out' thrown while requesting GET https://huggingface.co/datasets/wikimedia/wikipedia/resolve/b04c8d1ceb2f5cd4588862100d08de323dccfbaa/20231101.simple/train-00000-of-00001.parquet
# Retrying in 1s [Retry 1/5].
# ...
