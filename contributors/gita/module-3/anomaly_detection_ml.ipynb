# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# GENERATE SYNTHETIC DATA - FIRST : enable reproducity
np.random.seed(42)
# In practice we will load the data frame here
def generate_dataset(n_normal=300, n_anomaly=20, seed=42):
    rng=np.random.RandomState(seed)
    cluster_a=rng.multivariate_normal(
        mean=[0.0, 0.0],
        cov=[[1.2, 0.5], [0.5, 0.9]],
        size=int(n_normal * 0.55)
    )

    cluster_b=rng.multivariate_normal(
        mean=[5.0, 4.0],
        cov=[[0.9, -0.4], [-0.4, 1.1]],
        size=int(n_normal*0.45)
    )
    print(f"printing cluster_a: {cluster_a}")
    return cluster_a, cluster_b

# %%
cluster_a, cluster_b=generate_dataset()
def visualize_cluster_a(cluster_a=cluster_a, cluster_b=cluster_b):
    x1=cluster_a[:, 0]
    y1=cluster_a[:, 1]
    x2=cluster_b[:, 0]
    y2=cluster_b[:, 1]
    # create subplot
    fig, axes=plt.subplots(1, 2, figsize=(12, 5))
    # Plot 1: Actual cluster
    axes[0].scatter(x1, y1, alpha=0.8, s=50, color="REd")
    axes[0].set_title("Cluster A distribution")
    axes[0].set_xlabel("Feature X")
    axes[0].set_ylabel("Feature Y")
    axes[0].scatter(x2, y2, alpha=0.8, s=50, color="green")

    # PLOT 2: X vs Y relationship
    axes[1].plot(x1, y1, '-', alpha=0.7)
    axes[1].set_title("Covariance Relationship")
    axes[1].set_xlabel("x")
    axes[1].set_ylabel("Y")
    plt.tight_layout()
    plt.show()
visualize_cluster_a()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 cluster_a, cluster_b=generate_dataset()
#       2 def visualize_cluster_a(cluster_a=cluster_a, cluster_b=cluster_b):
#       3     x1=cluster_a[:, 0]
#
# Cell In[36], line 6, in generate_dataset(n_normal, n_anomaly, seed)
#       4 def generate_dataset(n_normal=300, n_anomaly=20, seed=42):
#       5     rng=np.random.RandomState(seed)
# ----> 6     cluster_a=rng.random.multivariate_normal(
#       7         mean=[0.0, 0.0],
#       8         cov=[[1.2, 0.5], [0.5, 0.9]],
#       9         size=int(n_normal * 0.55)
#      10     )
#      12     cluster_b=rng.multivariate_normal(
#      13         mean=[5.0, 4.0],
#      14         cov=[[0.9, -0.4], [-0.4, 1.1]],
#      15         size=int(n_normal*0.45)
#      16     )
#      17     print(f"printing cluster_a: {cluster_a}")
#
# AttributeError: '_cython_3_2_4.cython_function_or_method' object has no attribute 'multivariate_normal'
