# %% [markdown]
# # Download
# kaggle datasets download -d uciml/pima-indians-diabetes-database
#
# unzip pima-indians-diabetes-database.zip
# # OR
# wget https://raw.githubusercontent.com/npradaschnor/Pima-Indians-Diabetes-Dataset/master/diabetes.csv

# %%
# !kaggle datasets download -d uciml/pima-indians-diabetes-database
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/metadata/uciml/pima-indians-diabetes-database

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d uciml/pima-indians-diabetes-database
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/metadata/uciml/pima-indians-diabetes-database
