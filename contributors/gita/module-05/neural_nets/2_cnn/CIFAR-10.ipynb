# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
tf.random.set_seed(42)
np.random.seed(42)

CLASSES = ['airplane','automobile','bird','cat','deer',
'dog','frog','horse','ship','truck']
print("hello")
# Out:
# hello

# %%
# ── 1. DATA ───────────────────────────────────────────────
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
print(f"Train: {X_train.shape} | Test: {X_test.shape}")
print(f"Pixel range before norm: {X_train.min()} – {X_train.max()}")
# Normalize pixels to [0, 1]
X_train = X_train.astype(np.float32) / 255.0
X_test = X_test.astype(np.float32) / 255.0
# Flatten class labels [N, 1] → [N]
y_train = y_train.flatten()
y_test = y_test.flatten()
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce so we will re-download the data.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#  46350336/170498071 ━━━━━━━━━━━━━━━━━━━━ 3:21:17 97us/step
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# File C:\miniconda3\envs\deeplearning\lib\site-packages\keras\src\utils\file_utils.py:395, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     394 try:
# --> 395     urlretrieve(origin, download_target, DLProgbar())
#     396 except urllib.error.HTTPError as e:
#
# File C:\miniconda3\envs\deeplearning\lib\urllib\request.py:280, in urlretrieve(url, filename, reporthook, data)
#     279 if size >= 0 and read < size:
# --> 280     raise ContentTooShortError(
#     281         "retrieval incomplete: got only %i out of %i bytes"
#     282         % (read, size), result)
#     284 return result
#
# ContentTooShortError: <urlopen error retrieval incomplete: got only 46344000 out of 170498071 bytes>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # ── 1. DATA ───────────────────────────────────────────────
# ----> 2 (X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
#       3 print(f"Train: {X_train.shape} | Test: {X_test.shape}")
#       4 print(f"Pixel range before norm: {X_train.min()} – {X_train.max()}")
#
# File C:\miniconda3\envs\deeplearning\lib\site-packages\keras\src\datasets\cifar10.py:65, in load_data()
#      63 dirname = "cifar-10-batches-py-target"
#      64 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 65 path = get_file(
#      66     fname=dirname,
#      67     origin=origin,
#      68     extract=True,
#      69     file_hash=(  # noqa: E501
#      70         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      71     ),
#      72 )
#      74 num_train_samples = 50000
#      76 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File C:\miniconda3\envs\deeplearning\lib\site-packages\keras\src\utils\file_utils.py:399, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     397         raise Exception(error_msg.format(origin, e.code, e.msg))
#     398     except urllib.error.URLError as e:
# --> 399         raise Exception(error_msg.format(origin, e.errno, e.reason))
#     400 except (Exception, KeyboardInterrupt):
#     401     if os.path.exists(download_target):
#
# Exception: URL fetch failure on https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz: None -- retrieval incomplete: got only 46344000 out of 170498071 bytes

# %%
X_val = X_train[-5000:]
y_val = y_train[-5000:]
X_train = X_train[:-5000]
y_train = y_train[:-5000]
print(f"Train: {X_train.shape[0]} | Val: {X_val.shape[0]} | Test: {X_test.shape[0]}")
